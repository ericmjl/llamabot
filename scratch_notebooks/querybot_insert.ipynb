# %%
# %load_ext autoreload
# %autoreload 2

# %%
from llamabot import QueryBot 
from pyprojroot import here 


bot = QueryBot("You are a PDF Q&A bot.", doc_paths=[here() / "data/prot-eng.pdf"])
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total embedding token usage: 0 tokens
# 2023-05-12 16:35:07.631 | INFO     | llamabot.bot.querybot:insert_documents_into_index:191 - Inserting /Users/ema/projects/llamabot/data/prot-eng.pdf into the index...
# Looking in indexes: https://pypi.org/simple, https://pip.modernatx.net/
# Collecting PyPDF2 (from -r /Users/ema/anaconda/envs/llamabot/lib/python3.9/site-packages/llama_index/readers/llamahub_modules/file/pdf/requirements.txt (line 1))
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /Users/ema/anaconda/envs/llamabot/lib/python3.9/site-packages (from PyPDF2->-r /Users/ema/anaconda/envs/llamabot/lib/python3.9/site-packages/llama_index/readers/llamahub_modules/file/pdf/requirements.txt (line 1)) (4.5.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 986 tokens

# %%
bot.insert(here() / "data/bayesopt-chrom.pdf")
# Out:
# 2023-05-12 16:35:33.565 | INFO     | llamabot.bot.querybot:insert_documents_into_index:191 - Inserting /Users/ema/projects/llamabot/data/bayesopt-chrom.pdf into the index...
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 2000 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [insert] Total embedding token usage: 1996 tokens

# %%
bot.save(here() / "data/index.json")

# %%
chromatography_prompt = "Who are the authors of the chromatography paper?"
protein_engineering_prompt = "Who are the authors of the protein eng paper?"

# %%
bot(chromatography_prompt)
# Out:
# 2023-05-12 16:36:29.229 | INFO     | llamabot.bot.querybot:__call__:120 - Querying index for top 3 documents...
# INFO:llama_index.token_counter.token_counter:> [query] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [query] Total embedding token usage: 10 tokens
# The authors of the chromatography paper are Jim Boelrijk, Bernd Ensing, Patrick Forr˘ea, and Bob W.J. Pirok.
# AIMessage(content='The authors of the chromatography paper are Jim Boelrijk, Bernd Ensing, Patrick Forr˘ea, and Bob W.J. Pirok.', additional_kwargs={})

# %%
bot(protein_engineering_prompt)
# Out:
# 2023-05-12 16:36:38.645 | INFO     | llamabot.bot.querybot:__call__:120 - Querying index for top 3 documents...
# INFO:llama_index.token_counter.token_counter:> [query] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [query] Total embedding token usage: 10 tokens
# The authors of the protein engineering paper are Chase R Freschlin, Sarah A Fahlberg, and Philip A Romero.
# AIMessage(content='The authors of the protein engineering paper are Chase R Freschlin, Sarah A Fahlberg, and Philip A Romero.', additional_kwargs={})
